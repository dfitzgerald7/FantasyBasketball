# %% [markdown]
# # Daily Fantasy Basketball Predictions
#
# ## Get the player averages, info and salaries from draftkings, an example csv is in the repository
# ## Take the opponent and find the average points allowed by that team (based on basketball monster website)
# ## Adjust the average score of the player by the ratio of the avg points allowed by the opponent/ the average points allowed by all of the teams
# ## Multiplying by this ratio will hopefully somewhat adjust for competition of the night

# %% [markdown]
# $Player's Projected Points = Player's Avg Points * \frac{Avg Points Allowed By Opponent}{Avg Points Allowed By All Teams}$

# %% [markdown]
# ### Install necessary packages:

# %%
# Import for data analysis:
import numpy as np
import pandas as pd
# Import for web scraping:
import requests
from bs4 import BeautifulSoup
from html.parser import HTMLParser
import urllib.request
import csv

# %% [markdown]
# ### Get players from todays games, figure out their opponent :

# %%
# Get info from CSV downloaded from DraftKings... Better way to get CSV?  Download automatically somehow?
todays_players_df = pd.read_csv('DKSalaries.csv')

# Create new columns in dataframe for the opponent and the new projection updated based on opponent
todays_players_df["Opponent"] = "NA"
todays_players_df["Proj"] = todays_players_df["AvgPointsPerGame"]
#print(todays_players_df)

# List of all teams with abreviations that are 2 letters long, need this to find opponent team
two_letter_teams_list = ["GS", "NY", "NO","SA"]

# Loop through all players who are playing today
for playerstats in todays_players_df.iterrows():
    ############# Find Players Opponent #############
    gameInfo = playerstats[1]["Game Info"]
    playersTeam = playerstats[1]["TeamAbbrev"]
    # Ex:  want to get the team Harden is playing from game info string "HOU@NY 11/16/2019 08:00PM ET" 
    try:
        indexVs = gameInfo.index("@")
        # If the team before @ is not the players team, it is the opponent
        if (gameInfo[0:indexVs] != playersTeam):
            opposingTeam = gameInfo[0:indexVs]
        # Else if the team listed after the @ is the opponent and the team has 2 letters
        elif (gameInfo[indexVs:indexVs+2] in two_letter_teams_list):
            opposingTeam = gameInfo[indexVs+1:indexVs+3]
        else:
            opposingTeam = gameInfo[indexVs+1:indexVs+4]
    except:
        opposingTeam = "NA"
    
    # Store the opponents in another row in the playerstats dataframe
    # playerstats[0] is the index of the player in the dataframe
    todays_players_df.loc[playerstats[0],"Opponent"] = opposingTeam
    
print(todays_players_df)
# Out:
#     Position                          Name + ID                    Name  \
# 0      PG/SG            James Harden (13772382)            James Harden
# 1      SF/PF   Giannis Antetokounmpo (13772386)   Giannis Antetokounmpo
# 2      PG/SG             Luka Doncic (13772390)             Luka Doncic
# 3          C      Karl-Anthony Towns (13772394)      Karl-Anthony Towns
# 4      SF/PF           Kawhi Leonard (13772396)           Kawhi Leonard
# 5         PG              Trae Young (13772400)              Trae Young
# 6       PF/C           Pascal Siakam (13772403)           Pascal Siakam
# 7         PG          Damian Lillard (13772407)          Damian Lillard
# 8      PG/SG            Jrue Holiday (13772410)            Jrue Holiday
# 9       PF/C        Domantas Sabonis (13772414)        Domantas Sabonis
# 10     SG/SF          Andrew Wiggins (13772418)          Andrew Wiggins
# 11        PG       Russell Westbrook (13772423)       Russell Westbrook
# 12     SF/PF             Paul George (13772426)             Paul George
# 13         C            Clint Capela (13772430)            Clint Capela
# 14     SG/SF            Jimmy Butler (13772432)            Jimmy Butler
# 15         C             Bam Adebayo (13772437)             Bam Adebayo
# 16     PG/SG            Lou Williams (13772439)            Lou Williams
# 17        PG            Eric Bledsoe (13772443)            Eric Bledsoe
# 18     PG/SG         Devonte' Graham (13772451)         Devonte' Graham
# 19     SG/SF           DeMar DeRozan (13772446)           DeMar DeRozan
# 20     PG/SG           Fred VanVleet (13772455)           Fred VanVleet
# 21     SF/PF           Jabari Parker (13772463)           Jabari Parker
# 22      PF/C      Kristaps Porzingis (13772459)      Kristaps Porzingis
# 23      PF/C        Montrezl Harrell (13772467)        Montrezl Harrell
# 24     SF/PF          Brandon Ingram (13772471)          Brandon Ingram
# 25     PG/SG         Malcolm Brogdon (13772475)         Malcolm Brogdon
# 26        PG              Kyle Lowry (13772479)              Kyle Lowry
# 27        PG            Terry Rozier (13772482)            Terry Rozier
# 28      PF/C       LaMarcus Aldridge (13772485)       LaMarcus Aldridge
# 29     PG/SG             CJ McCollum (13772489)             CJ McCollum
# ..       ...                                ...                     ...
# 206    SG/SF        Cameron Reynolds (13773147)        Cameron Reynolds
# 207    PG/SG         Frank Mason III (13773152)         Frank Mason III
# 208    SF/PF  Thanasis Antetokounmpo (13773156)  Thanasis Antetokounmpo
# 209     PF/C             D.J. Wilson (13773160)             D.J. Wilson
# 210     PF/C           Dragan Bender (13773164)           Dragan Bender
# 211     PF/C            Zach Collins (13772988)            Zach Collins
# 212    SF/PF         DeMarre Carroll (13773074)         DeMarre Carroll
# 213     PF/C            Drew Eubanks (13773078)            Drew Eubanks
# 214       PG  Quinndary Weatherspoon (13773082)  Quinndary Weatherspoon
# 215    SG/SF        Lonnie Walker IV (13773085)        Lonnie Walker IV
# 216    SG/SF          Keldon Johnson (13773090)          Keldon Johnson
# 217    SF/PF            Luka Samanic (13773095)            Luka Samanic
# 218        C               Pau Gasol (13773239)               Pau Gasol
# 219        C            Jusuf Nurkic (13773241)            Jusuf Nurkic
# 220    SF/PF            Jaylen Hoard (13773243)            Jaylen Hoard
# 221        C             Moses Brown (13773247)             Moses Brown
# 222    PG/SG              J.J. Barea (13773099)              J.J. Barea
# 223    SG/SF            Courtney Lee (13773103)            Courtney Lee
# 224    SG/SF          Ryan Broekhoff (13773108)          Ryan Broekhoff
# 225       SG      Antonius Cleveland (13773113)      Antonius Cleveland
# 226    SF/PF          Justin Jackson (13773116)          Justin Jackson
# 227       SG             Josh Reaves (13773120)             Josh Reaves
# 228    SF/PF             Isaiah Roby (13773123)             Isaiah Roby
# 229    SG/SF          Malcolm Miller (13773249)          Malcolm Miller
# 230       SG             Matt Thomas (13773254)             Matt Thomas
# 231    SF/PF         Stanley Johnson (13773257)         Stanley Johnson
# 232    PG/SG           Patrick McCaw (13773261)           Patrick McCaw
# 233     PF/C         Dewan Hernandez (13773265)         Dewan Hernandez
# 234       PG          Shamorie Ponds (13773269)          Shamorie Ponds
# 235    SF/PF          Oshae Brissett (13773272)          Oshae Brissett
#
#            ID Roster Position  Salary                      Game Info  \
# 0    13772382    PG/SG/G/UTIL   12200  HOU@MIN 11/16/2019 08:00PM ET
# 1    13772386    SF/PF/F/UTIL   12000  MIL@IND 11/16/2019 07:00PM ET
# 2    13772390    PG/SG/G/UTIL   10300  TOR@DAL 11/16/2019 08:30PM ET
# 3    13772394          C/UTIL   10100  HOU@MIN 11/16/2019 08:00PM ET
# 4    13772396    SF/PF/F/UTIL    9900  ATL@LAC 11/16/2019 10:30PM ET
# 5    13772400       PG/G/UTIL    9400  ATL@LAC 11/16/2019 10:30PM ET
# 6    13772403     PF/C/F/UTIL    9200  TOR@DAL 11/16/2019 08:30PM ET
# 7    13772407       PG/G/UTIL    8700   POR@SA 11/16/2019 08:30PM ET
# 8    13772410    PG/SG/G/UTIL    8600   NO@MIA 11/16/2019 08:00PM ET
# 9    13772414     PF/C/F/UTIL    8500  MIL@IND 11/16/2019 07:00PM ET
# 10   13772418  SG/SF/F/G/UTIL    8400  HOU@MIN 11/16/2019 08:00PM ET
# 11   13772423       PG/G/UTIL    8300  HOU@MIN 11/16/2019 08:00PM ET
# 12   13772426    SF/PF/F/UTIL    7900  ATL@LAC 11/16/2019 10:30PM ET
# 13   13772430          C/UTIL    7700  HOU@MIN 11/16/2019 08:00PM ET
# 14   13772432  SG/SF/F/G/UTIL    7600   NO@MIA 11/16/2019 08:00PM ET
# 15   13772437          C/UTIL    7500   NO@MIA 11/16/2019 08:00PM ET
# 16   13772439    PG/SG/G/UTIL    7400  ATL@LAC 11/16/2019 10:30PM ET
# 17   13772443       PG/G/UTIL    7300  MIL@IND 11/16/2019 07:00PM ET
# 18   13772451    PG/SG/G/UTIL    7200   CHA@NY 11/16/2019 07:30PM ET
# 19   13772446  SG/SF/F/G/UTIL    7200   POR@SA 11/16/2019 08:30PM ET
# 20   13772455    PG/SG/G/UTIL    7100  TOR@DAL 11/16/2019 08:30PM ET
# 21   13772463    SF/PF/F/UTIL    7000  ATL@LAC 11/16/2019 10:30PM ET
# 22   13772459     PF/C/F/UTIL    7000  TOR@DAL 11/16/2019 08:30PM ET
# 23   13772467     PF/C/F/UTIL    6900  ATL@LAC 11/16/2019 10:30PM ET
# 24   13772471    SF/PF/F/UTIL    6900   NO@MIA 11/16/2019 08:00PM ET
# 25   13772475    PG/SG/G/UTIL    6900  MIL@IND 11/16/2019 07:00PM ET
# 26   13772479       PG/G/UTIL    6800  TOR@DAL 11/16/2019 08:30PM ET
# 27   13772482       PG/G/UTIL    6700   CHA@NY 11/16/2019 07:30PM ET
# 28   13772485     PF/C/F/UTIL    6600   POR@SA 11/16/2019 08:30PM ET
# 29   13772489    PG/SG/G/UTIL    6500   POR@SA 11/16/2019 08:30PM ET
# ..        ...             ...     ...                            ...
# 206  13773147  SG/SF/F/G/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 207  13773152    PG/SG/G/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 208  13773156    SF/PF/F/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 209  13773160     PF/C/F/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 210  13773164     PF/C/F/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 211  13772988     PF/C/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 212  13773074    SF/PF/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 213  13773078     PF/C/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 214  13773082       PG/G/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 215  13773085  SG/SF/F/G/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 216  13773090  SG/SF/F/G/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 217  13773095    SF/PF/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 218  13773239          C/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 219  13773241          C/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 220  13773243    SF/PF/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 221  13773247          C/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 222  13773099    PG/SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 223  13773103  SG/SF/F/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 224  13773108  SG/SF/F/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 225  13773113       SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 226  13773116    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 227  13773120       SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 228  13773123    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 229  13773249  SG/SF/F/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 230  13773254       SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 231  13773257    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 232  13773261    PG/SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 233  13773265     PF/C/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 234  13773269       PG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 235  13773272    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
#
#     TeamAbbrev  AvgPointsPerGame Opponent   Proj
# 0          HOU             62.33      MIN  62.33
# 1          MIL             64.48      IND  64.48
# 2          DAL             59.93      TOR  59.93
# 3          MIN             54.85      HOU  54.85
# 4          LAC             52.67      ATL  52.67
# 5          ATL             49.30      LAC  49.30
# 6          TOR             47.20      DAL  47.20
# 7          POR             51.19      SA   51.19
# 8           NO             39.92      MIA  39.92
# 9          IND             44.58      MIL  44.58
# 10         MIN             41.77      HOU  41.77
# 11         HOU             45.16      MIN  45.16
# 12         LAC             49.25      ATL  49.25
# 13         HOU             37.07      MIN  37.07
# 14         MIA             41.81       NO  41.81
# 15         MIA             38.57       NO  38.57
# 16         LAC             37.29      ATL  37.29
# 17         MIL             34.07      IND  34.07
# 18         CHA             36.17      NY   36.17
# 19          SA             34.83      POR  34.83
# 20         TOR             37.73      DAL  37.73
# 21         ATL             31.34      LAC  31.34
# 22         DAL             37.15      TOR  37.15
# 23         LAC             34.73      ATL  34.73
# 24          NO             44.28      MIA  44.28
# 25         IND             39.79      MIL  39.79
# 26         TOR             39.94      DAL  39.94
# 27         CHA             32.04      NY   32.04
# 28          SA             32.85      POR  32.85
# 29         POR             32.56      SA   32.56
# ..         ...               ...      ...    ...
# 206        MIL              0.00      IND   0.00
# 207        MIL              0.00      IND   0.00
# 208        MIL              6.00      IND   6.00
# 209        MIL              3.25      IND   3.25
# 210        MIL              0.00      IND   0.00
# 211        POR             17.83      SA   17.83
# 212         SA              7.56      POR   7.56
# 213         SA              3.25      POR   3.25
# 214         SA              0.00      POR   0.00
# 215         SA              2.64      POR   2.64
# 216         SA              0.00      POR   0.00
# 217         SA              0.00      POR   0.00
# 218        POR              0.00      SA    0.00
# 219        POR              0.00      SA    0.00
# 220        POR              1.25      SA    1.25
# 221        POR              1.88      SA    1.88
# 222        DAL             17.25      TOR  17.25
# 223        DAL              3.08      TOR   3.08
# 224        DAL              2.50      TOR   2.50
# 225        DAL              0.00      TOR   0.00
# 226        DAL             10.48      TOR  10.48
# 227        DAL              0.00      TOR   0.00
# 228        DAL              0.00      TOR   0.00
# 229        TOR              2.00      DAL   2.00
# 230        TOR              7.50      DAL   7.50
# 231        TOR              3.25      DAL   3.25
# 232        TOR             12.50      DAL  12.50
# 233        TOR              0.00      DAL   0.00
# 234        TOR              0.00      DAL   0.00
# 235        TOR              0.00      DAL   0.00
#
# [236 rows x 11 columns]

# %% [markdown]
# ### Get the avg points allowed by each team, for now stick with total, not per position

# %%
# Following BeautifulSoup beginners tutorial
URL = 'https://basketballmonster.com/dfsdvp.aspx'
response = requests.get(URL)
soup = BeautifulSoup(response.content, 'html.parser')
labels = []
data = []
rows=list()
    
table = soup.find_all('table')[0] 

# df is a list of all of the found data frames. len = 1
df = pd.read_html(str(table))
# So the dataframe we want to use is the only one found at index 0
df_opponentPtsAllowed = df[0]

# Take out "vs " in the "Team" column 
for row in df2.index:
    df_opponentPtsAllowed.loc[row,"Team"] = df2.loc[row,"Team"][0][3:]

# Make the indexing column be the Team
# Note:  For some reason when just using the "Team" collumn directly, the indecies become tuples
df_opponentPtsAllowed["TeamStr"] = df2["Team"]
df_opponentPtsAllowed = df_opponentPtsAllowed.set_index("TeamStr")

print(df_opponentPtsAllowed)
# Out:
#                       Team     g    All    PG    SG    SF    PF     C
#         Unnamed: 0_level_1   Avg  224.1  46.2  41.7  40.3  44.3  51.8
# TeamStr
# NaN                 vs ATL  67.0  242.3  47.9  44.8  45.8  47.8  56.0
# NaN                 vs CLE  65.0  238.3  50.4  44.8  43.8  45.8  53.4
# NaN                 vs WAS  64.0  234.1  49.4  43.0  42.5  45.3  54.4
# NaN                 vs MIN  64.0  233.1  48.1  44.4  42.0  46.5  52.8
# NaN                 vs GSW  65.0  233.0  49.3  43.9  42.4  44.6  53.0
# NaN                 vs NOR  64.0  232.2  50.3  42.8  41.2  46.2  52.9
# NaN                 vs POR  66.0  232.0  48.4  42.0  40.8  47.1  54.3
# NaN                 vs HOU  64.0  231.0  46.9  43.7  41.6  47.5  51.9
# NaN                 vs MEM  65.0  230.2  46.7  43.9  41.7  45.1  52.8
# NaN                 vs CHA  65.0  228.4  43.9  42.0  40.4  46.8  55.8
# NaN                 vs PHO  65.0  227.0  46.7  42.4  40.8  44.2  52.9
# NaN                 vs DET  66.0  226.4  45.6  41.4  38.9  45.3  54.9
# NaN                 vs SAS  63.0  226.4  47.3  42.9  40.7  44.9  50.8
# NaN                 vs CHI  65.0  226.3  41.4  39.3  40.6  48.1  56.7
# NaN                 vs BKN  64.0  224.5  48.1  40.4  39.4  42.6  54.8
# NaN                 vs NYK  66.0  223.5  47.6  41.7  39.1  45.7  49.5
# NaN                 vs LAC  64.0  223.1  45.5  40.7  39.9  43.7  53.0
# NaN                 vs DAL  67.0  220.7  45.0  40.7  41.2  43.4  51.0
# NaN                 vs TOR  64.0  220.1  43.9  41.8  41.2  45.0  48.3
# NaN                 vs SAC  64.0  219.9  46.6  42.8  40.1  40.8  49.5
# NaN                 vs MIL  65.0  219.5  45.9  40.4  38.9  43.1  51.6
# NaN                 vs ORL  65.0  218.9  45.7  40.7  39.5  45.2  48.2
# NaN                 vs UTA  64.0  215.8  45.6  40.6  37.1  42.0  51.1
# NaN                 vs MIA  65.0  215.6  43.7  41.4  39.3  42.1  49.1
# NaN                 vs DEN  65.0  215.5  44.8  39.1  38.6  42.0  51.0
# NaN                 vs IND  65.0  214.8  44.9  40.3  36.8  41.4  51.7
# NaN                 vs BOS  64.0  214.5  43.6  40.8  37.8  43.3  49.5
# NaN                 vs OKC  64.0  213.9  44.9  39.0  38.1  40.7  51.0
# NaN                 vs LAL  63.0  212.6  46.3  40.0  39.1  41.0  46.4
# NaN                 vs PHI  65.0  209.6  42.6  40.0  38.7  41.9  46.6
# ATL                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# CLE                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# WAS                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# MIN                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# GSW                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# NOR                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# POR                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# HOU                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# MEM                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# CHA                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# PHO                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# DET                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# SAS                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# CHI                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# BKN                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# NYK                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# LAC                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# DAL                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# TOR                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# SAC                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# MIL                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# ORL                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# UTA                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# MIA                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# DEN                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# IND                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# BOS                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# OKC                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# LAL                          NaN    NaN   NaN   NaN   NaN   NaN   NaN
# PHI                          NaN    NaN   NaN   NaN   NaN   NaN   NaN

# %%
print(df_opponentPtsAllowed.loc["ATL","All"][0])
# Out:
# nan

# %% [markdown]
# ### Adjust the players projected score based on their opponents avg points allowed, for now stick with total, not per position

# %%
avgAllTeams = df2.columns.levels[1][0]
print(avgAllTeams)

# Loop through all players who are playing today
for i, playerstats in todays_players_df.iterrows():
    print("**************************************************")
    print("Original Info: ")
    print(playerstats)
    # The Two letter teams cause issues again, better solution for this?
    opponent = playerstats["Opponent"].strip()
    if (opponent == "SA"):
        opponent = "SAS"
    elif(opponent == "GS"):
        opponent = "SAS"
    elif(opponent == "NO"):
        opponent = "NOR"
    elif(opponent == "NY"):
        opponent = "NYK"
        
    print("Points allowed by opponent/avg of all teams: "+str(df2.loc[opponent,"All"][0]/ float(avgAllTeams)))
    print("*************************")
    todays_players_df.loc[i,"Proj"] = todays_players_df.loc[i,"AvgPointsPerGame"] * (df_opponentPtsAllowed.loc[opponent,"All"][0]/ float(avgAllTeams))
    
    # print(playerstats)
    print(todays_players_df.loc[i,"Proj"])
# Out:
# 224.1
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID                 James Harden (13772382)
# Name                                 James Harden
# ID                                       13772382
# Roster Position                      PG/SG/G/UTIL
# Salary                                      12200
# Game Info           HOU@MIN 11/16/2019 08:00PM ET
# TeamAbbrev                                    HOU
# AvgPointsPerGame                            62.33
# Opponent                                      MIN
# Proj                                        62.33
# Name: 0, dtype: object
# Points allowed by opponent/avg of all teams: 1.0401606425702812
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       SF/PF
# Name + ID           Giannis Antetokounmpo (13772386)
# Name                           Giannis Antetokounmpo
# ID                                          13772386
# Roster Position                         SF/PF/F/UTIL
# Salary                                         12000
# Game Info              MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                       MIL
# AvgPointsPerGame                               64.48
# Opponent                                         IND
# Proj                                           64.48
# Name: 1, dtype: object
# Points allowed by opponent/avg of all teams: 0.9585006693440429
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID                  Luka Doncic (13772390)
# Name                                  Luka Doncic
# ID                                       13772390
# Roster Position                      PG/SG/G/UTIL
# Salary                                      10300
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                            59.93
# Opponent                                      TOR
# Proj                                        59.93
# Name: 2, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                        C
# Name + ID           Karl-Anthony Towns (13772394)
# Name                           Karl-Anthony Towns
# ID                                       13772394
# Roster Position                            C/UTIL
# Salary                                      10100
# Game Info           HOU@MIN 11/16/2019 08:00PM ET
# TeamAbbrev                                    MIN
# AvgPointsPerGame                            54.85
# Opponent                                      HOU
# Proj                                        54.85
# Name: 3, dtype: object
# Points allowed by opponent/avg of all teams: 1.0307898259705488
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID                Kawhi Leonard (13772396)
# Name                                Kawhi Leonard
# ID                                       13772396
# Roster Position                      SF/PF/F/UTIL
# Salary                                       9900
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    LAC
# AvgPointsPerGame                            52.67
# Opponent                                      ATL
# Proj                                        52.67
# Name: 4, dtype: object
# Points allowed by opponent/avg of all teams: 1.0812137438643463
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       PG
# Name + ID                   Trae Young (13772400)
# Name                                   Trae Young
# ID                                       13772400
# Roster Position                         PG/G/UTIL
# Salary                                       9400
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    ATL
# AvgPointsPerGame                             49.3
# Opponent                                      LAC
# Proj                                         49.3
# Name: 5, dtype: object
# Points allowed by opponent/avg of all teams: 0.9955377063810799
# *************************
# nan
# **************************************************
# Original Info:
# Position                                     PF/C
# Name + ID                Pascal Siakam (13772403)
# Name                                Pascal Siakam
# ID                                       13772403
# Roster Position                       PF/C/F/UTIL
# Salary                                       9200
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                             47.2
# Opponent                                      DAL
# Proj                                         47.2
# Name: 6, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                      PG
# Name + ID              Damian Lillard (13772407)
# Name                              Damian Lillard
# ID                                      13772407
# Roster Position                        PG/G/UTIL
# Salary                                      8700
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# AvgPointsPerGame                           51.19
# Opponent                                     SA
# Proj                                       51.19
# Name: 7, dtype: object
# Points allowed by opponent/avg of all teams: 1.0102632753235163
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   PG/SG
# Name + ID                Jrue Holiday (13772410)
# Name                                Jrue Holiday
# ID                                      13772410
# Roster Position                     PG/SG/G/UTIL
# Salary                                      8600
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                    NO
# AvgPointsPerGame                           39.92
# Opponent                                     MIA
# Proj                                       39.92
# Name: 8, dtype: object
# Points allowed by opponent/avg of all teams: 0.962070504239179
# *************************
# nan
# **************************************************
# Original Info:
# Position                                     PF/C
# Name + ID             Domantas Sabonis (13772414)
# Name                             Domantas Sabonis
# ID                                       13772414
# Roster Position                       PF/C/F/UTIL
# Salary                                       8500
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    IND
# AvgPointsPerGame                            44.58
# Opponent                                      MIL
# Proj                                        44.58
# Name: 9, dtype: object
# Points allowed by opponent/avg of all teams: 0.9794734493529674
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SG/SF
# Name + ID               Andrew Wiggins (13772418)
# Name                               Andrew Wiggins
# ID                                       13772418
# Roster Position                    SG/SF/F/G/UTIL
# Salary                                       8400
# Game Info           HOU@MIN 11/16/2019 08:00PM ET
# TeamAbbrev                                    MIN
# AvgPointsPerGame                            41.77
# Opponent                                      HOU
# Proj                                        41.77
# Name: 10, dtype: object
# Points allowed by opponent/avg of all teams: 1.0307898259705488
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       PG
# Name + ID            Russell Westbrook (13772423)
# Name                            Russell Westbrook
# ID                                       13772423
# Roster Position                         PG/G/UTIL
# Salary                                       8300
# Game Info           HOU@MIN 11/16/2019 08:00PM ET
# TeamAbbrev                                    HOU
# AvgPointsPerGame                            45.16
# Opponent                                      MIN
# Proj                                        45.16
# Name: 11, dtype: object
# Points allowed by opponent/avg of all teams: 1.0401606425702812
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID                  Paul George (13772426)
# Name                                  Paul George
# ID                                       13772426
# Roster Position                      SF/PF/F/UTIL
# Salary                                       7900
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    LAC
# AvgPointsPerGame                            49.25
# Opponent                                      ATL
# Proj                                        49.25
# Name: 12, dtype: object
# Points allowed by opponent/avg of all teams: 1.0812137438643463
# *************************
# nan
# **************************************************
# Original Info:
# Position                                        C
# Name + ID                 Clint Capela (13772430)
# Name                                 Clint Capela
# ID                                       13772430
# Roster Position                            C/UTIL
# Salary                                       7700
# Game Info           HOU@MIN 11/16/2019 08:00PM ET
# TeamAbbrev                                    HOU
# AvgPointsPerGame                            37.07
# Opponent                                      MIN
# Proj                                        37.07
# Name: 13, dtype: object
# Points allowed by opponent/avg of all teams: 1.0401606425702812
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SG/SF
# Name + ID                Jimmy Butler (13772432)
# Name                                Jimmy Butler
# ID                                      13772432
# Roster Position                   SG/SF/F/G/UTIL
# Salary                                      7600
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                   MIA
# AvgPointsPerGame                           41.81
# Opponent                                      NO
# Proj                                       41.81
# Name: 14, dtype: object
# Points allowed by opponent/avg of all teams: 1.036144578313253
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       C
# Name + ID                 Bam Adebayo (13772437)
# Name                                 Bam Adebayo
# ID                                      13772437
# Roster Position                           C/UTIL
# Salary                                      7500
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                   MIA
# AvgPointsPerGame                           38.57
# Opponent                                      NO
# Proj                                       38.57
# Name: 15, dtype: object
# Points allowed by opponent/avg of all teams: 1.036144578313253
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID                 Lou Williams (13772439)
# Name                                 Lou Williams
# ID                                       13772439
# Roster Position                      PG/SG/G/UTIL
# Salary                                       7400
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    LAC
# AvgPointsPerGame                            37.29
# Opponent                                      ATL
# Proj                                        37.29
# Name: 16, dtype: object
# Points allowed by opponent/avg of all teams: 1.0812137438643463
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       PG
# Name + ID                 Eric Bledsoe (13772443)
# Name                                 Eric Bledsoe
# ID                                       13772443
# Roster Position                         PG/G/UTIL
# Salary                                       7300
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    MIL
# AvgPointsPerGame                            34.07
# Opponent                                      IND
# Proj                                        34.07
# Name: 17, dtype: object
# Points allowed by opponent/avg of all teams: 0.9585006693440429
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   PG/SG
# Name + ID             Devonte' Graham (13772451)
# Name                             Devonte' Graham
# ID                                      13772451
# Roster Position                     PG/SG/G/UTIL
# Salary                                      7200
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                   CHA
# AvgPointsPerGame                           36.17
# Opponent                                     NY
# Proj                                       36.17
# Name: 18, dtype: object
# Points allowed by opponent/avg of all teams: 0.997322623828648
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SG/SF
# Name + ID               DeMar DeRozan (13772446)
# Name                               DeMar DeRozan
# ID                                      13772446
# Roster Position                   SG/SF/F/G/UTIL
# Salary                                      7200
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                    SA
# AvgPointsPerGame                           34.83
# Opponent                                     POR
# Proj                                       34.83
# Name: 19, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID                Fred VanVleet (13772455)
# Name                                Fred VanVleet
# ID                                       13772455
# Roster Position                      PG/SG/G/UTIL
# Salary                                       7100
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                            37.73
# Opponent                                      DAL
# Proj                                        37.73
# Name: 20, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID                Jabari Parker (13772463)
# Name                                Jabari Parker
# ID                                       13772463
# Roster Position                      SF/PF/F/UTIL
# Salary                                       7000
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    ATL
# AvgPointsPerGame                            31.34
# Opponent                                      LAC
# Proj                                        31.34
# Name: 21, dtype: object
# Points allowed by opponent/avg of all teams: 0.9955377063810799
# *************************
# nan
# **************************************************
# Original Info:
# Position                                     PF/C
# Name + ID           Kristaps Porzingis (13772459)
# Name                           Kristaps Porzingis
# ID                                       13772459
# Roster Position                       PF/C/F/UTIL
# Salary                                       7000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                            37.15
# Opponent                                      TOR
# Proj                                        37.15
# Name: 22, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                     PF/C
# Name + ID             Montrezl Harrell (13772467)
# Name                             Montrezl Harrell
# ID                                       13772467
# Roster Position                       PF/C/F/UTIL
# Salary                                       6900
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    LAC
# AvgPointsPerGame                            34.73
# Opponent                                      ATL
# Proj                                        34.73
# Name: 23, dtype: object
# Points allowed by opponent/avg of all teams: 1.0812137438643463
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SF/PF
# Name + ID              Brandon Ingram (13772471)
# Name                              Brandon Ingram
# ID                                      13772471
# Roster Position                     SF/PF/F/UTIL
# Salary                                      6900
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                    NO
# AvgPointsPerGame                           44.28
# Opponent                                     MIA
# Proj                                       44.28
# Name: 24, dtype: object
# Points allowed by opponent/avg of all teams: 0.962070504239179
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID              Malcolm Brogdon (13772475)
# Name                              Malcolm Brogdon
# ID                                       13772475
# Roster Position                      PG/SG/G/UTIL
# Salary                                       6900
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    IND
# AvgPointsPerGame                            39.79
# Opponent                                      MIL
# Proj                                        39.79
# Name: 25, dtype: object
# Points allowed by opponent/avg of all teams: 0.9794734493529674
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       PG
# Name + ID                   Kyle Lowry (13772479)
# Name                                   Kyle Lowry
# ID                                       13772479
# Roster Position                         PG/G/UTIL
# Salary                                       6800
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                            39.94
# Opponent                                      DAL
# Proj                                        39.94
# Name: 26, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                      PG
# Name + ID                Terry Rozier (13772482)
# Name                                Terry Rozier
# ID                                      13772482
# Roster Position                        PG/G/UTIL
# Salary                                      6700
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                   CHA
# AvgPointsPerGame                           32.04
# Opponent                                     NY
# Proj                                       32.04
# Name: 27, dtype: object
# Points allowed by opponent/avg of all teams: 0.997322623828648
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PF/C
# Name + ID           LaMarcus Aldridge (13772485)
# Name                           LaMarcus Aldridge
# ID                                      13772485
# Roster Position                      PF/C/F/UTIL
# Salary                                      6600
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                    SA
# AvgPointsPerGame                           32.85
# Opponent                                     POR
# Proj                                       32.85
# Name: 28, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   PG/SG
# Name + ID                 CJ McCollum (13772489)
# Name                                 CJ McCollum
# ID                                      13772489
# Roster Position                     PG/SG/G/UTIL
# Salary                                      6500
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# AvgPointsPerGame                           32.56
# Opponent                                     SA
# Proj                                       32.56
# Name: 29, dtype: object
# Points allowed by opponent/avg of all teams: 1.0102632753235163
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PF/C
# Name + ID               Julius Randle (13772493)
# Name                               Julius Randle
# ID                                      13772493
# Roster Position                      PF/C/F/UTIL
# Salary                                      6400
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                    NY
# AvgPointsPerGame                           34.46
# Opponent                                     CHA
# Proj                                       34.46
# Name: 30, dtype: object
# Points allowed by opponent/avg of all teams: 1.0191878625613566
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       C
# Name + ID            Hassan Whiteside (13772497)
# Name                            Hassan Whiteside
# ID                                      13772497
# Roster Position                           C/UTIL
# Salary                                      6300
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# AvgPointsPerGame                           35.59
# Opponent                                     SA
# Proj                                       35.59
# Name: 31, dtype: object
# Points allowed by opponent/avg of all teams: 1.0102632753235163
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PF/C
# Name + ID              Derrick Favors (13772499)
# Name                              Derrick Favors
# ID                                      13772499
# Roster Position                      PF/C/F/UTIL
# Salary                                      6200
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                    NO
# AvgPointsPerGame                           26.03
# Opponent                                     MIA
# Proj                                       26.03
# Name: 32, dtype: object
# Points allowed by opponent/avg of all teams: 0.962070504239179
# *************************
# nan
# **************************************************
# Original Info:
# Position                                        C
# Name + ID                 Myles Turner (13772503)
# Name                                 Myles Turner
# ID                                       13772503
# Roster Position                            C/UTIL
# Salary                                       6100
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    IND
# AvgPointsPerGame                            27.94
# Opponent                                      MIL
# Proj                                        27.94
# Name: 33, dtype: object
# Points allowed by opponent/avg of all teams: 0.9794734493529674
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SF/PF
# Name + ID               Marcus Morris (13772505)
# Name                               Marcus Morris
# ID                                      13772505
# Roster Position                     SF/PF/F/UTIL
# Salary                                      6000
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                    NY
# AvgPointsPerGame                           31.52
# Opponent                                     CHA
# Proj                                       31.52
# Name: 34, dtype: object
# Points allowed by opponent/avg of all teams: 1.0191878625613566
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SG/SF
# Name + ID                  Jeremy Lamb (13772509)
# Name                                  Jeremy Lamb
# ID                                       13772509
# Roster Position                    SG/SF/F/G/UTIL
# Salary                                       6000
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    IND
# AvgPointsPerGame                               33
# Opponent                                      MIL
# Proj                                           33
# Name: 35, dtype: object
# Points allowed by opponent/avg of all teams: 0.9794734493529674
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   PG/SF
# Name + ID             Justise Winslow (13772514)
# Name                             Justise Winslow
# ID                                      13772514
# Roster Position                   PG/SF/F/G/UTIL
# Salary                                      5900
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                   MIA
# AvgPointsPerGame                            33.2
# Opponent                                      NO
# Proj                                        33.2
# Name: 36, dtype: object
# Points allowed by opponent/avg of all teams: 1.036144578313253
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   PG/SG
# Name + ID               Kendrick Nunn (13772519)
# Name                               Kendrick Nunn
# ID                                      13772519
# Roster Position                     PG/SG/G/UTIL
# Salary                                      5800
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                   MIA
# AvgPointsPerGame                           29.41
# Opponent                                      NO
# Proj                                       29.41
# Name: 37, dtype: object
# Points allowed by opponent/avg of all teams: 1.036144578313253
# *************************
# nan
# **************************************************
# Original Info:
# Position                                      PG
# Name + ID                  Lonzo Ball (13772523)
# Name                                  Lonzo Ball
# ID                                      13772523
# Roster Position                        PG/G/UTIL
# Salary                                      5800
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                    NO
# AvgPointsPerGame                           29.94
# Opponent                                     MIA
# Proj                                       29.94
# Name: 38, dtype: object
# Points allowed by opponent/avg of all teams: 0.962070504239179
# *************************
# nan
# **************************************************
# Original Info:
# Position                                      PG
# Name + ID                Goran Dragic (13772530)
# Name                                Goran Dragic
# ID                                      13772530
# Roster Position                        PG/G/UTIL
# Salary                                      5700
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                   MIA
# AvgPointsPerGame                            29.7
# Opponent                                      NO
# Proj                                        29.7
# Name: 39, dtype: object
# Points allowed by opponent/avg of all teams: 1.036144578313253
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID                  T.J. Warren (13772526)
# Name                                  T.J. Warren
# ID                                       13772526
# Roster Position                      SF/PF/F/UTIL
# Salary                                       5700
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    IND
# AvgPointsPerGame                            26.46
# Opponent                                      MIL
# Proj                                        26.46
# Name: 40, dtype: object
# Points allowed by opponent/avg of all teams: 0.9794734493529674
# *************************
# nan
# **************************************************
# Original Info:
# Position                                        C
# Name + ID                   Marc Gasol (13772533)
# Name                                   Marc Gasol
# ID                                       13772533
# Roster Position                            C/UTIL
# Salary                                       5700
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                            20.98
# Opponent                                      DAL
# Proj                                        20.98
# Name: 41, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   PG/SG
# Name + ID                  RJ Barrett (13772535)
# Name                                  RJ Barrett
# ID                                      13772535
# Roster Position                     PG/SG/G/UTIL
# Salary                                      5600
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                    NY
# AvgPointsPerGame                           31.06
# Opponent                                     CHA
# Proj                                       31.06
# Name: 42, dtype: object
# Points allowed by opponent/avg of all teams: 1.0191878625613566
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SF/PF
# Name + ID               Miles Bridges (13772539)
# Name                               Miles Bridges
# ID                                      13772539
# Roster Position                     SF/PF/F/UTIL
# Salary                                      5600
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                   CHA
# AvgPointsPerGame                           24.54
# Opponent                                     NY
# Proj                                       24.54
# Name: 43, dtype: object
# Points allowed by opponent/avg of all teams: 0.997322623828648
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       C
# Name + ID                 Cody Zeller (13772543)
# Name                                 Cody Zeller
# ID                                      13772543
# Roster Position                           C/UTIL
# Salary                                      5500
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                   CHA
# AvgPointsPerGame                           28.84
# Opponent                                     NY
# Proj                                       28.84
# Name: 44, dtype: object
# Points allowed by opponent/avg of all teams: 0.997322623828648
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SG/SF
# Name + ID                   Josh Hart (13772545)
# Name                                   Josh Hart
# ID                                      13772545
# Roster Position                   SG/SF/F/G/UTIL
# Salary                                      5400
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                    NO
# AvgPointsPerGame                           27.38
# Opponent                                     MIA
# Proj                                       27.38
# Name: 45, dtype: object
# Points allowed by opponent/avg of all teams: 0.962070504239179
# *************************
# nan
# **************************************************
# Original Info:
# Position                                         SF/PF
# Name + ID           Rondae Hollis-Jefferson (13772550)
# Name                           Rondae Hollis-Jefferson
# ID                                            13772550
# Roster Position                           SF/PF/F/UTIL
# Salary                                            5400
# Game Info                TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                         TOR
# AvgPointsPerGame                                 20.31
# Opponent                                           DAL
# Proj                                             20.31
# Name: 46, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SF/PF
# Name + ID            Kenrich Williams (13772554)
# Name                            Kenrich Williams
# ID                                      13772554
# Roster Position                     SF/PF/F/UTIL
# Salary                                      5300
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                    NO
# AvgPointsPerGame                            19.3
# Opponent                                     MIA
# Proj                                        19.3
# Name: 47, dtype: object
# Points allowed by opponent/avg of all teams: 0.962070504239179
# *************************
# nan
# **************************************************
# Original Info:
# Position                                     PF/C
# Name + ID                  Serge Ibaka (13772558)
# Name                                  Serge Ibaka
# ID                                       13772558
# Roster Position                       PF/C/F/UTIL
# Salary                                       5300
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                            26.25
# Opponent                                      DAL
# Proj                                        26.25
# Name: 48, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                      PG
# Name + ID             Dejounte Murray (13772562)
# Name                             Dejounte Murray
# ID                                      13772562
# Roster Position                        PG/G/UTIL
# Salary                                      5200
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                    SA
# AvgPointsPerGame                           29.68
# Opponent                                     POR
# Proj                                       29.68
# Name: 49, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       PG
# Name + ID                  Jeff Teague (13772565)
# Name                                  Jeff Teague
# ID                                       13772565
# Roster Position                         PG/G/UTIL
# Salary                                       5100
# Game Info           HOU@MIN 11/16/2019 08:00PM ET
# TeamAbbrev                                    MIN
# AvgPointsPerGame                            29.12
# Opponent                                      HOU
# Proj                                        29.12
# Name: 50, dtype: object
# Points allowed by opponent/avg of all teams: 1.0307898259705488
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   PG/SG
# Name + ID                  Malik Monk (13772568)
# Name                                  Malik Monk
# ID                                      13772568
# Roster Position                     PG/SG/G/UTIL
# Salary                                      5000
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                   CHA
# AvgPointsPerGame                           17.58
# Opponent                                     NY
# Proj                                       17.58
# Name: 51, dtype: object
# Points allowed by opponent/avg of all teams: 0.997322623828648
# *************************
# nan
# **************************************************
# Original Info:
# Position                                      PG
# Name + ID            Dennis Smith Jr. (13772572)
# Name                            Dennis Smith Jr.
# ID                                      13772572
# Roster Position                        PG/G/UTIL
# Salary                                      5000
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                    NY
# AvgPointsPerGame                            9.95
# Opponent                                     CHA
# Proj                                        9.95
# Name: 52, dtype: object
# Points allowed by opponent/avg of all teams: 1.0191878625613566
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SG/SF
# Name + ID                   JJ Redick (13772583)
# Name                                   JJ Redick
# ID                                      13772583
# Roster Position                   SG/SF/F/G/UTIL
# Salary                                      4900
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                    NO
# AvgPointsPerGame                           19.77
# Opponent                                     MIA
# Proj                                       19.77
# Name: 53, dtype: object
# Points allowed by opponent/avg of all teams: 0.962070504239179
# *************************
# nan
# **************************************************
# Original Info:
# Position                                        C
# Name + ID                  Brook Lopez (13772575)
# Name                                  Brook Lopez
# ID                                       13772575
# Roster Position                            C/UTIL
# Salary                                       4900
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    MIL
# AvgPointsPerGame                            23.61
# Opponent                                      IND
# Proj                                        23.61
# Name: 54, dtype: object
# Points allowed by opponent/avg of all teams: 0.9585006693440429
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID                Aaron Holiday (13772579)
# Name                                Aaron Holiday
# ID                                       13772579
# Roster Position                      PG/SG/G/UTIL
# Salary                                       4900
# Game Info           MIL@IND 11/16/2019 07:00PM ET
# TeamAbbrev                                    IND
# AvgPointsPerGame                            17.82
# Opponent                                      MIL
# Proj                                        17.82
# Name: 55, dtype: object
# Points allowed by opponent/avg of all teams: 0.9794734493529674
# *************************
# nan
# **************************************************
# Original Info:
# Position                                        C
# Name + ID                Dwight Powell (13772577)
# Name                                Dwight Powell
# ID                                       13772577
# Roster Position                            C/UTIL
# Salary                                       4900
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                            19.31
# Opponent                                      TOR
# Proj                                        19.31
# Name: 56, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PF/C
# Name + ID               PJ Washington (13772592)
# Name                               PJ Washington
# ID                                      13772592
# Roster Position                      PF/C/F/UTIL
# Salary                                      4800
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                   CHA
# AvgPointsPerGame                           26.46
# Opponent                                     NY
# Proj                                       26.46
# Name: 57, dtype: object
# Points allowed by opponent/avg of all teams: 0.997322623828648
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID             Robert Covington (13772588)
# Name                             Robert Covington
# ID                                       13772588
# Roster Position                      SF/PF/F/UTIL
# Salary                                       4800
# Game Info           HOU@MIN 11/16/2019 08:00PM ET
# TeamAbbrev                                    MIN
# AvgPointsPerGame                            26.17
# Opponent                                      HOU
# Proj                                        26.17
# Name: 58, dtype: object
# Points allowed by opponent/avg of all teams: 1.0307898259705488
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SF/PF
# Name + ID                    Rudy Gay (13772600)
# Name                                    Rudy Gay
# ID                                      13772600
# Roster Position                     SF/PF/F/UTIL
# Salary                                      4800
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                    SA
# AvgPointsPerGame                           24.21
# Opponent                                     POR
# Proj                                       24.21
# Name: 59, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID                   OG Anunoby (13772596)
# Name                                   OG Anunoby
# ID                                       13772596
# Roster Position                      SF/PF/F/UTIL
# Salary                                       4800
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                            26.85
# Opponent                                      DAL
# Proj                                        26.85
# Name: 60, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PF/C
# Name + ID                Bobby Portis (13772608)
# Name                                Bobby Portis
# ID                                      13772608
# Roster Position                      PF/C/F/UTIL
# Salary                                      4700
# Game Info           CHA@NY 11/16/2019 07:30PM ET
# TeamAbbrev                                    NY
# AvgPointsPerGame                           23.17
# Opponent                                     CHA
# Proj                                       23.17
# Name: 61, dtype: object
# Points allowed by opponent/avg of all teams: 1.0191878625613566
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID              De'Andre Hunter (13772604)
# Name                              De'Andre Hunter
# ID                                       13772604
# Roster Position                      SF/PF/F/UTIL
# Salary                                       4700
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    ATL
# AvgPointsPerGame                            19.36
# Opponent                                      LAC
# Proj                                        19.36
# Name: 62, dtype: object
# Points allowed by opponent/avg of all teams: 0.9955377063810799
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID             Patrick Beverley (13772612)
# Name                             Patrick Beverley
# ID                                       13772612
# Roster Position                      PG/SG/G/UTIL
# Salary                                       4600
# Game Info           ATL@LAC 11/16/2019 10:30PM ET
# TeamAbbrev                                    LAC
# AvgPointsPerGame                            22.77
# Opponent                                      ATL
# Proj                                        22.77
# Name: 63, dtype: object
# Points allowed by opponent/avg of all teams: 1.0812137438643463
# *************************
# nan
# **************************************************
# Original Info:
# Position                                      SG
# Name + ID                 Tyler Herro (13772616)
# Name                                 Tyler Herro
# ID                                      13772616
# Roster Position                        SG/G/UTIL
# Salary                                      4600
# Game Info           NO@MIA 11/16/2019 08:00PM ET
# TeamAbbrev                                   MIA
# AvgPointsPerGame                           23.75
# Opponent                                      NO
# Proj                                       23.75
# Name: 64, dtype: object
# Points allowed by opponent/avg of all teams: 1.036144578313253
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SG/SF
# Name + ID                 Rodney Hood (13772619)
# Name                                 Rodney Hood
# ID                                      13772619
# Roster Position                   SG/SF/F/G/UTIL
# Salary                                      4600
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# ...
# Name                           Quinndary Weatherspoon
# ID                                           13773082
# Roster Position                             PG/G/UTIL
# Salary                                           3000
# Game Info                POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                         SA
# AvgPointsPerGame                                    0
# Opponent                                          POR
# Proj                                                0
# Name: 214, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SG/SF
# Name + ID            Lonnie Walker IV (13773085)
# Name                            Lonnie Walker IV
# ID                                      13773085
# Roster Position                   SG/SF/F/G/UTIL
# Salary                                      3000
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                    SA
# AvgPointsPerGame                            2.64
# Opponent                                     POR
# Proj                                        2.64
# Name: 215, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SG/SF
# Name + ID              Keldon Johnson (13773090)
# Name                              Keldon Johnson
# ID                                      13773090
# Roster Position                   SG/SF/F/G/UTIL
# Salary                                      3000
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                    SA
# AvgPointsPerGame                               0
# Opponent                                     POR
# Proj                                           0
# Name: 216, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SF/PF
# Name + ID                Luka Samanic (13773095)
# Name                                Luka Samanic
# ID                                      13773095
# Roster Position                     SF/PF/F/UTIL
# Salary                                      3000
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                    SA
# AvgPointsPerGame                               0
# Opponent                                     POR
# Proj                                           0
# Name: 217, dtype: object
# Points allowed by opponent/avg of all teams: 1.035252119589469
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       C
# Name + ID                   Pau Gasol (13773239)
# Name                                   Pau Gasol
# ID                                      13773239
# Roster Position                           C/UTIL
# Salary                                      3000
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# AvgPointsPerGame                               0
# Opponent                                     SA
# Proj                                           0
# Name: 218, dtype: object
# Points allowed by opponent/avg of all teams: 1.0102632753235163
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       C
# Name + ID                Jusuf Nurkic (13773241)
# Name                                Jusuf Nurkic
# ID                                      13773241
# Roster Position                           C/UTIL
# Salary                                      3000
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# AvgPointsPerGame                               0
# Opponent                                     SA
# Proj                                           0
# Name: 219, dtype: object
# Points allowed by opponent/avg of all teams: 1.0102632753235163
# *************************
# nan
# **************************************************
# Original Info:
# Position                                   SF/PF
# Name + ID                Jaylen Hoard (13773243)
# Name                                Jaylen Hoard
# ID                                      13773243
# Roster Position                     SF/PF/F/UTIL
# Salary                                      3000
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# AvgPointsPerGame                            1.25
# Opponent                                     SA
# Proj                                        1.25
# Name: 220, dtype: object
# Points allowed by opponent/avg of all teams: 1.0102632753235163
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       C
# Name + ID                 Moses Brown (13773247)
# Name                                 Moses Brown
# ID                                      13773247
# Roster Position                           C/UTIL
# Salary                                      3000
# Game Info           POR@SA 11/16/2019 08:30PM ET
# TeamAbbrev                                   POR
# AvgPointsPerGame                            1.88
# Opponent                                     SA
# Proj                                        1.88
# Name: 221, dtype: object
# Points allowed by opponent/avg of all teams: 1.0102632753235163
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID                   J.J. Barea (13773099)
# Name                                   J.J. Barea
# ID                                       13773099
# Roster Position                      PG/SG/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                            17.25
# Opponent                                      TOR
# Proj                                        17.25
# Name: 222, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SG/SF
# Name + ID                 Courtney Lee (13773103)
# Name                                 Courtney Lee
# ID                                       13773103
# Roster Position                    SG/SF/F/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                             3.08
# Opponent                                      TOR
# Proj                                         3.08
# Name: 223, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SG/SF
# Name + ID               Ryan Broekhoff (13773108)
# Name                               Ryan Broekhoff
# ID                                       13773108
# Roster Position                    SG/SF/F/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                              2.5
# Opponent                                      TOR
# Proj                                          2.5
# Name: 224, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       SG
# Name + ID           Antonius Cleveland (13773113)
# Name                           Antonius Cleveland
# ID                                       13773113
# Roster Position                         SG/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                                0
# Opponent                                      TOR
# Proj                                            0
# Name: 225, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID               Justin Jackson (13773116)
# Name                               Justin Jackson
# ID                                       13773116
# Roster Position                      SF/PF/F/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                            10.48
# Opponent                                      TOR
# Proj                                        10.48
# Name: 226, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       SG
# Name + ID                  Josh Reaves (13773120)
# Name                                  Josh Reaves
# ID                                       13773120
# Roster Position                         SG/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                                0
# Opponent                                      TOR
# Proj                                            0
# Name: 227, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID                  Isaiah Roby (13773123)
# Name                                  Isaiah Roby
# ID                                       13773123
# Roster Position                      SF/PF/F/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    DAL
# AvgPointsPerGame                                0
# Opponent                                      TOR
# Proj                                            0
# Name: 228, dtype: object
# Points allowed by opponent/avg of all teams: 0.9821508255243195
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SG/SF
# Name + ID               Malcolm Miller (13773249)
# Name                               Malcolm Miller
# ID                                       13773249
# Roster Position                    SG/SF/F/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                                2
# Opponent                                      DAL
# Proj                                            2
# Name: 229, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       SG
# Name + ID                  Matt Thomas (13773254)
# Name                                  Matt Thomas
# ID                                       13773254
# Roster Position                         SG/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                              7.5
# Opponent                                      DAL
# Proj                                          7.5
# Name: 230, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID              Stanley Johnson (13773257)
# Name                              Stanley Johnson
# ID                                       13773257
# Roster Position                      SF/PF/F/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                             3.25
# Opponent                                      DAL
# Proj                                         3.25
# Name: 231, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    PG/SG
# Name + ID                Patrick McCaw (13773261)
# Name                                Patrick McCaw
# ID                                       13773261
# Roster Position                      PG/SG/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                             12.5
# Opponent                                      DAL
# Proj                                         12.5
# Name: 232, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                     PF/C
# Name + ID              Dewan Hernandez (13773265)
# Name                              Dewan Hernandez
# ID                                       13773265
# Roster Position                       PF/C/F/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                                0
# Opponent                                      DAL
# Proj                                            0
# Name: 233, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                       PG
# Name + ID               Shamorie Ponds (13773269)
# Name                               Shamorie Ponds
# ID                                       13773269
# Roster Position                         PG/G/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                                0
# Opponent                                      DAL
# Proj                                            0
# Name: 234, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan
# **************************************************
# Original Info:
# Position                                    SF/PF
# Name + ID               Oshae Brissett (13773272)
# Name                               Oshae Brissett
# ID                                       13773272
# Roster Position                      SF/PF/F/UTIL
# Salary                                       3000
# Game Info           TOR@DAL 11/16/2019 08:30PM ET
# TeamAbbrev                                    TOR
# AvgPointsPerGame                                0
# Opponent                                      DAL
# Proj                                            0
# Name: 235, dtype: object
# Points allowed by opponent/avg of all teams: 0.9848282016956715
# *************************
# nan

# %%
print(todays_players_df)
# Out:
#     Position                          Name + ID                    Name  \
# 0      PG/SG            James Harden (13772382)            James Harden
# 1      SF/PF   Giannis Antetokounmpo (13772386)   Giannis Antetokounmpo
# 2      PG/SG             Luka Doncic (13772390)             Luka Doncic
# 3          C      Karl-Anthony Towns (13772394)      Karl-Anthony Towns
# 4      SF/PF           Kawhi Leonard (13772396)           Kawhi Leonard
# 5         PG              Trae Young (13772400)              Trae Young
# 6       PF/C           Pascal Siakam (13772403)           Pascal Siakam
# 7         PG          Damian Lillard (13772407)          Damian Lillard
# 8      PG/SG            Jrue Holiday (13772410)            Jrue Holiday
# 9       PF/C        Domantas Sabonis (13772414)        Domantas Sabonis
# 10     SG/SF          Andrew Wiggins (13772418)          Andrew Wiggins
# 11        PG       Russell Westbrook (13772423)       Russell Westbrook
# 12     SF/PF             Paul George (13772426)             Paul George
# 13         C            Clint Capela (13772430)            Clint Capela
# 14     SG/SF            Jimmy Butler (13772432)            Jimmy Butler
# 15         C             Bam Adebayo (13772437)             Bam Adebayo
# 16     PG/SG            Lou Williams (13772439)            Lou Williams
# 17        PG            Eric Bledsoe (13772443)            Eric Bledsoe
# 18     PG/SG         Devonte' Graham (13772451)         Devonte' Graham
# 19     SG/SF           DeMar DeRozan (13772446)           DeMar DeRozan
# 20     PG/SG           Fred VanVleet (13772455)           Fred VanVleet
# 21     SF/PF           Jabari Parker (13772463)           Jabari Parker
# 22      PF/C      Kristaps Porzingis (13772459)      Kristaps Porzingis
# 23      PF/C        Montrezl Harrell (13772467)        Montrezl Harrell
# 24     SF/PF          Brandon Ingram (13772471)          Brandon Ingram
# 25     PG/SG         Malcolm Brogdon (13772475)         Malcolm Brogdon
# 26        PG              Kyle Lowry (13772479)              Kyle Lowry
# 27        PG            Terry Rozier (13772482)            Terry Rozier
# 28      PF/C       LaMarcus Aldridge (13772485)       LaMarcus Aldridge
# 29     PG/SG             CJ McCollum (13772489)             CJ McCollum
# ..       ...                                ...                     ...
# 206    SG/SF        Cameron Reynolds (13773147)        Cameron Reynolds
# 207    PG/SG         Frank Mason III (13773152)         Frank Mason III
# 208    SF/PF  Thanasis Antetokounmpo (13773156)  Thanasis Antetokounmpo
# 209     PF/C             D.J. Wilson (13773160)             D.J. Wilson
# 210     PF/C           Dragan Bender (13773164)           Dragan Bender
# 211     PF/C            Zach Collins (13772988)            Zach Collins
# 212    SF/PF         DeMarre Carroll (13773074)         DeMarre Carroll
# 213     PF/C            Drew Eubanks (13773078)            Drew Eubanks
# 214       PG  Quinndary Weatherspoon (13773082)  Quinndary Weatherspoon
# 215    SG/SF        Lonnie Walker IV (13773085)        Lonnie Walker IV
# 216    SG/SF          Keldon Johnson (13773090)          Keldon Johnson
# 217    SF/PF            Luka Samanic (13773095)            Luka Samanic
# 218        C               Pau Gasol (13773239)               Pau Gasol
# 219        C            Jusuf Nurkic (13773241)            Jusuf Nurkic
# 220    SF/PF            Jaylen Hoard (13773243)            Jaylen Hoard
# 221        C             Moses Brown (13773247)             Moses Brown
# 222    PG/SG              J.J. Barea (13773099)              J.J. Barea
# 223    SG/SF            Courtney Lee (13773103)            Courtney Lee
# 224    SG/SF          Ryan Broekhoff (13773108)          Ryan Broekhoff
# 225       SG      Antonius Cleveland (13773113)      Antonius Cleveland
# 226    SF/PF          Justin Jackson (13773116)          Justin Jackson
# 227       SG             Josh Reaves (13773120)             Josh Reaves
# 228    SF/PF             Isaiah Roby (13773123)             Isaiah Roby
# 229    SG/SF          Malcolm Miller (13773249)          Malcolm Miller
# 230       SG             Matt Thomas (13773254)             Matt Thomas
# 231    SF/PF         Stanley Johnson (13773257)         Stanley Johnson
# 232    PG/SG           Patrick McCaw (13773261)           Patrick McCaw
# 233     PF/C         Dewan Hernandez (13773265)         Dewan Hernandez
# 234       PG          Shamorie Ponds (13773269)          Shamorie Ponds
# 235    SF/PF          Oshae Brissett (13773272)          Oshae Brissett
#
#            ID Roster Position  Salary                      Game Info  \
# 0    13772382    PG/SG/G/UTIL   12200  HOU@MIN 11/16/2019 08:00PM ET
# 1    13772386    SF/PF/F/UTIL   12000  MIL@IND 11/16/2019 07:00PM ET
# 2    13772390    PG/SG/G/UTIL   10300  TOR@DAL 11/16/2019 08:30PM ET
# 3    13772394          C/UTIL   10100  HOU@MIN 11/16/2019 08:00PM ET
# 4    13772396    SF/PF/F/UTIL    9900  ATL@LAC 11/16/2019 10:30PM ET
# 5    13772400       PG/G/UTIL    9400  ATL@LAC 11/16/2019 10:30PM ET
# 6    13772403     PF/C/F/UTIL    9200  TOR@DAL 11/16/2019 08:30PM ET
# 7    13772407       PG/G/UTIL    8700   POR@SA 11/16/2019 08:30PM ET
# 8    13772410    PG/SG/G/UTIL    8600   NO@MIA 11/16/2019 08:00PM ET
# 9    13772414     PF/C/F/UTIL    8500  MIL@IND 11/16/2019 07:00PM ET
# 10   13772418  SG/SF/F/G/UTIL    8400  HOU@MIN 11/16/2019 08:00PM ET
# 11   13772423       PG/G/UTIL    8300  HOU@MIN 11/16/2019 08:00PM ET
# 12   13772426    SF/PF/F/UTIL    7900  ATL@LAC 11/16/2019 10:30PM ET
# 13   13772430          C/UTIL    7700  HOU@MIN 11/16/2019 08:00PM ET
# 14   13772432  SG/SF/F/G/UTIL    7600   NO@MIA 11/16/2019 08:00PM ET
# 15   13772437          C/UTIL    7500   NO@MIA 11/16/2019 08:00PM ET
# 16   13772439    PG/SG/G/UTIL    7400  ATL@LAC 11/16/2019 10:30PM ET
# 17   13772443       PG/G/UTIL    7300  MIL@IND 11/16/2019 07:00PM ET
# 18   13772451    PG/SG/G/UTIL    7200   CHA@NY 11/16/2019 07:30PM ET
# 19   13772446  SG/SF/F/G/UTIL    7200   POR@SA 11/16/2019 08:30PM ET
# 20   13772455    PG/SG/G/UTIL    7100  TOR@DAL 11/16/2019 08:30PM ET
# 21   13772463    SF/PF/F/UTIL    7000  ATL@LAC 11/16/2019 10:30PM ET
# 22   13772459     PF/C/F/UTIL    7000  TOR@DAL 11/16/2019 08:30PM ET
# 23   13772467     PF/C/F/UTIL    6900  ATL@LAC 11/16/2019 10:30PM ET
# 24   13772471    SF/PF/F/UTIL    6900   NO@MIA 11/16/2019 08:00PM ET
# 25   13772475    PG/SG/G/UTIL    6900  MIL@IND 11/16/2019 07:00PM ET
# 26   13772479       PG/G/UTIL    6800  TOR@DAL 11/16/2019 08:30PM ET
# 27   13772482       PG/G/UTIL    6700   CHA@NY 11/16/2019 07:30PM ET
# 28   13772485     PF/C/F/UTIL    6600   POR@SA 11/16/2019 08:30PM ET
# 29   13772489    PG/SG/G/UTIL    6500   POR@SA 11/16/2019 08:30PM ET
# ..        ...             ...     ...                            ...
# 206  13773147  SG/SF/F/G/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 207  13773152    PG/SG/G/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 208  13773156    SF/PF/F/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 209  13773160     PF/C/F/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 210  13773164     PF/C/F/UTIL    3000  MIL@IND 11/16/2019 07:00PM ET
# 211  13772988     PF/C/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 212  13773074    SF/PF/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 213  13773078     PF/C/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 214  13773082       PG/G/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 215  13773085  SG/SF/F/G/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 216  13773090  SG/SF/F/G/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 217  13773095    SF/PF/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 218  13773239          C/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 219  13773241          C/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 220  13773243    SF/PF/F/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 221  13773247          C/UTIL    3000   POR@SA 11/16/2019 08:30PM ET
# 222  13773099    PG/SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 223  13773103  SG/SF/F/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 224  13773108  SG/SF/F/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 225  13773113       SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 226  13773116    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 227  13773120       SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 228  13773123    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 229  13773249  SG/SF/F/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 230  13773254       SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 231  13773257    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 232  13773261    PG/SG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 233  13773265     PF/C/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 234  13773269       PG/G/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
# 235  13773272    SF/PF/F/UTIL    3000  TOR@DAL 11/16/2019 08:30PM ET
#
#     TeamAbbrev  AvgPointsPerGame Opponent  Proj
# 0          HOU             62.33      MIN   NaN
# 1          MIL             64.48      IND   NaN
# 2          DAL             59.93      TOR   NaN
# 3          MIN             54.85      HOU   NaN
# 4          LAC             52.67      ATL   NaN
# 5          ATL             49.30      LAC   NaN
# 6          TOR             47.20      DAL   NaN
# 7          POR             51.19      SA    NaN
# 8           NO             39.92      MIA   NaN
# 9          IND             44.58      MIL   NaN
# 10         MIN             41.77      HOU   NaN
# 11         HOU             45.16      MIN   NaN
# 12         LAC             49.25      ATL   NaN
# 13         HOU             37.07      MIN   NaN
# 14         MIA             41.81       NO   NaN
# 15         MIA             38.57       NO   NaN
# 16         LAC             37.29      ATL   NaN
# 17         MIL             34.07      IND   NaN
# 18         CHA             36.17      NY    NaN
# 19          SA             34.83      POR   NaN
# 20         TOR             37.73      DAL   NaN
# 21         ATL             31.34      LAC   NaN
# 22         DAL             37.15      TOR   NaN
# 23         LAC             34.73      ATL   NaN
# 24          NO             44.28      MIA   NaN
# 25         IND             39.79      MIL   NaN
# 26         TOR             39.94      DAL   NaN
# 27         CHA             32.04      NY    NaN
# 28          SA             32.85      POR   NaN
# 29         POR             32.56      SA    NaN
# ..         ...               ...      ...   ...
# 206        MIL              0.00      IND   NaN
# 207        MIL              0.00      IND   NaN
# 208        MIL              6.00      IND   NaN
# 209        MIL              3.25      IND   NaN
# 210        MIL              0.00      IND   NaN
# 211        POR             17.83      SA    NaN
# 212         SA              7.56      POR   NaN
# 213         SA              3.25      POR   NaN
# 214         SA              0.00      POR   NaN
# 215         SA              2.64      POR   NaN
# 216         SA              0.00      POR   NaN
# 217         SA              0.00      POR   NaN
# 218        POR              0.00      SA    NaN
# 219        POR              0.00      SA    NaN
# 220        POR              1.25      SA    NaN
# 221        POR              1.88      SA    NaN
# 222        DAL             17.25      TOR   NaN
# 223        DAL              3.08      TOR   NaN
# 224        DAL              2.50      TOR   NaN
# 225        DAL              0.00      TOR   NaN
# 226        DAL             10.48      TOR   NaN
# 227        DAL              0.00      TOR   NaN
# 228        DAL              0.00      TOR   NaN
# 229        TOR              2.00      DAL   NaN
# 230        TOR              7.50      DAL   NaN
# 231        TOR              3.25      DAL   NaN
# 232        TOR             12.50      DAL   NaN
# 233        TOR              0.00      DAL   NaN
# 234        TOR              0.00      DAL   NaN
# 235        TOR              0.00      DAL   NaN
#
# [236 rows x 11 columns]
